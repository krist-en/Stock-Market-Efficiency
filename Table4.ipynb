# %% [markdown]
# **Table 4: FF Regression**
#
# For this code, datasets required:
# - CSV: market_cap, FF3, FF3Y, FF5, FFMOM, HXZ, at_HML(Table2 output), at_df_yret(Table2 output), portfolio_at2(Table2 output)
# - XLSX: rf6023

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

# %%
# merge yret data with at_df
portfolio_at = pd.read_csv('portfolio_at2.csv')
market_cap=pd.read_csv('market_cap.csv') # monthly mktcap for each gvkey, with year and month num
rf = pd.read_excel('rf6023.xlsx')
print(rf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    64 non-null     int64
#  1   rf      64 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB
# None

# %%
# creat year and month
market_cap['MthCalDt'] = pd.to_datetime(market_cap['MthCalDt'], format='%Y/%m/%d')
market_cap['year'] = market_cap['MthCalDt'].dt.year
market_cap['month'] = market_cap['MthCalDt'].dt.month
market_cap = market_cap.drop(columns=['MthCalDt'])
print(market_cap.describe())
market_cap.head()
# Out:
#              PERMNO        MthCap          gvkey          year         month
# count  21692.000000  2.169200e+04   21692.000000  21692.000000  21692.000000
# mean   77955.165775  4.584563e+06  153503.101835   2011.761110      6.515029
# std    27012.647796  9.662385e+06   32019.133455      6.162657      3.457175
# min    12009.000000  3.681480e+03  105365.000000   1996.000000      1.000000
# 25%    86316.000000  4.906814e+05  127575.000000   2007.000000      4.000000
# 50%    88917.000000  1.467253e+06  155394.000000   2012.000000      7.000000
# 75%    90870.000000  4.103633e+06  175404.000000   2017.000000     10.000000
# max    93387.000000  1.332086e+08  315318.000000   2023.000000     12.000000
#    PERMNO      MthCap   gvkey  year  month
# 0   86111   376581.19  105365  1998      6
# 1   86111  2269944.00  105365  1998      7
# 2   86111  1489650.75  105365  1998      8
# 3   86111  2411815.50  105365  1998      9
# 4   86111  2068959.38  105365  1998     10

# %%
def ffreg(target,features,datay,dataX): # target is 'string input', features is list of 'string variables'
  data = dataX.merge(datay,on=['year','month'],how='inner')
  X = sm.add_constant(data[features]) # add constant term for alpha estimation
  y = data[target]
  model = sm.OLS(y, X).fit()
  print(model.summary())

# %%
# create data with monthly return and group tag
market_cap['mret'] = (market_cap['MthCap'] / market_cap['MthCap'].shift(1) - 1)*100
market_cap = market_cap.dropna(subset=['mret'])
mret = market_cap[['gvkey','year','month','mret','MthCap']]
mret = pd.merge(portfolio_at[['fyear','gvkey','group_tag']],mret,left_on=['gvkey','fyear'],right_on=['gvkey','year'], how='inner')
mret = mret.merge(rf, on='year',how='inner')
mret = mret.drop('fyear',axis=1)
mret.head()
# Out:
#     gvkey group_tag  year  month        mret      MthCap    rf
# 0  105365         H  1998      7  502.776788  2269944.00  4.33
# 1  105365         H  1998      8  -34.375000  1489650.75  4.33
# 2  105365         H  1998      9   61.904762  2411815.50  4.33
# 3  105365         H  1998     10  -14.215686  2068959.38  4.33
# 4  105365         H  1998     11    7.499271  2224116.25  4.33

# %%
# datay: H-L month return
H = mret[mret['group_tag']=='H']
L = mret[mret['group_tag']=='L']

# Filter the original DataFrame to include only rows where tag is 'H'
m_ret_H = pd.DataFrame(columns = ['year','month','mret_H'])
for year in H['year'].unique():
    groupret_m_H = {}
    year_H = H[H['year'] == year].copy()
    for month in year_H['month'].unique():
      month_H = year_H[year_H['month'] == month].copy()
      month_H['weight'] = month_H['MthCap'] / month_H['MthCap'].sum()
      m_H_ret = (month_H['mret'] * month_H['weight']).sum()
      groupret_m_H[month] = m_H_ret
    groupret_m_H = pd.DataFrame(list(groupret_m_H.items()), columns=['month', 'mret_H'])
    groupret_m_H['year'] = year*np.ones(len(groupret_m_H)).astype(int)
    m_ret_H = pd.concat([m_ret_H, groupret_m_H], ignore_index=True)

# Filter the original DataFrame to include only rows where tag is 'L'
m_ret_L = pd.DataFrame(columns = ['year','month','mret_L'])
for year in L['year'].unique():
    groupret_m_L = {}
    year_L = L[L['year'] == year].copy()
    for month in year_L['month'].unique():
      month_L = year_L[year_L['month'] == month].copy()
      month_L['weight'] = month_L['MthCap'] / month_L['MthCap'].sum()
      m_L_ret = (month_L['mret'] * month_L['weight']).sum()
      groupret_m_L[month] = m_L_ret
    groupret_m_L = pd.DataFrame(list(groupret_m_L.items()), columns=['month', 'mret_L'])
    groupret_m_L['year'] = year * np.ones(len(groupret_m_L)).astype(int)
    m_ret_L = pd.concat([m_ret_L, groupret_m_L], ignore_index=True)

H_L = pd.merge(m_ret_H, m_ret_L, on=['year','month'], how='inner')
H_L['mret'] = H_L['mret_H']- H_L['mret_L'] # for regression convenience, we name H-L ret as 'ret_prem'
print(H_L)
# Out:
#      year month      mret_H     mret_L        mret
# 0    1998     7  181.184974   7.513312  173.671661
# 1    1998     8  -15.875810 -18.971726    3.095917
# 2    1998     9   25.613813 -43.882740   69.496553
# 3    1998    10   -6.259527  17.096958  -23.356485
# 4    1998    11    8.660271  19.268675  -10.608403
# ..    ...   ...         ...        ...         ...
# 292  2022     8   -5.695190   1.341448   -7.036638
# 293  2022     9  -10.727473  -5.440631   -5.286842
# 294  2022    10    4.433824  15.705974  -11.272150
# 295  2022    11   10.812030   2.487602    8.324428
# 296  2022    12   -9.486876  -3.018951   -6.467924
#
# [297 rows x 5 columns]

# %%
#split target in groups
tagl = mret[mret['group_tag']== 'L']
tag2 = mret[mret['group_tag']== '2']
tag3 = mret[mret['group_tag']== '3']
tag4 = mret[mret['group_tag']== '4']
tagh = mret[mret['group_tag']== 'H']
taghl = H_L
datay =[tagl,tag2,tag3,tag4,tagh,taghl]
taghl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    297 non-null    object
#  1   month   297 non-null    object
#  2   mret_H  297 non-null    float64
#  3   mret_L  297 non-null    float64
#  4   mret    297 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 11.7+ KB

# %%
# load features
ff3 = pd.read_csv('FF3.csv').dropna()
ffmom = pd.read_csv('FFMOM.csv').dropna()
ff5 = pd.read_csv('FF5.csv').dropna()
print(ff3.info())
print(ffmom.info())
print(ff5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1173 non-null   int64
#  1   MKT     1173 non-null   float64
#  2   SMB     1173 non-null   float64
#  3   HML     1173 non-null   float64
#  4   rf      1173 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 45.9 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1167 non-null   int64
#  1   MOM     1167 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 18.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    729 non-null    int64
#  1   MKT     729 non-null    float64
#  2   SMB     729 non-null    float64
#  3   HML     729 non-null    float64
#  4   RMW     729 non-null    float64
#  5   CMA     729 non-null    float64
#  6   rf      729 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 40.0 KB
# None

# %%
# seperate date in feature data into 'year' and 'month'
# Extract first 4 digits of 'date' for year, and last 2 digits for month
dataX = [ff3,ffmom,ff5]
for i in dataX:
  i['date'] = i['date'].astype(int)
  i['year'] = i['date'] // 100
  i['month'] = i['date'] % 100
  print(i.head())

ff3 = ff3.drop(columns=['date'])
ffmom = ffmom.drop(columns=['date'])
ff5 = ff5.drop(columns=['date'])
# merge MOM with FF3
ffmom_merge = ff3.merge(ffmom,on=['year','month'],how='inner')
ffmom_merge
# Out:
#      date   MKT   SMB   HML    rf  year  month
# 0  192607  2.96 -2.56 -2.43  0.22  1926      7
# 1  192608  2.64 -1.17  3.82  0.25  1926      8
# 2  192609  0.36 -1.40  0.13  0.23  1926      9
# 3  192610 -3.24 -0.09  0.70  0.32  1926     10
# 4  192611  2.53 -0.10 -0.51  0.31  1926     11
#      date   MOM  year  month
# 0  192701  0.36  1927      1
# 1  192702 -2.14  1927      2
# 2  192703  3.61  1927      3
# 3  192704  4.30  1927      4
# 4  192705  3.00  1927      5
#      date   MKT   SMB   HML   RMW   CMA    rf  year  month
# 0  196307 -0.39 -0.41 -0.97  0.68 -1.18  0.27  1963      7
# 1  196308  5.07 -0.80  1.80  0.36 -0.35  0.25  1963      8
# 2  196309 -1.57 -0.52  0.13 -0.71  0.29  0.27  1963      9
# 3  196310  2.53 -1.39 -0.10  2.80 -2.01  0.29  1963     10
# 4  196311 -0.85 -0.88  1.75 -0.51  2.24  0.27  1963     11
#        MKT   SMB   HML    rf  year  month   MOM
# 0    -0.06 -0.37  4.54  0.25  1927      1  0.36
# 1     4.18  0.04  2.94  0.26  1927      2 -2.14
# 2     0.13 -1.65 -2.61  0.30  1927      3  3.61
# 3     0.46  0.30  0.81  0.25  1927      4  4.30
# 4     5.44  1.53  4.73  0.30  1927      5  3.00
# ...    ...   ...   ...   ...   ...    ...   ...
# 1162  8.84 -0.02  1.64  0.44  2023     11  2.75
# 1163  4.87  6.34  4.93  0.43  2023     12 -5.51
# 1164  0.71 -5.09 -2.38  0.47  2024      1  5.19
# 1165  5.06 -0.24 -3.49  0.42  2024      2  4.96
# 1166  2.83 -2.49  4.19  0.43  2024      3 -0.42
#
# [1167 rows x 7 columns]

# %%
# seperate regression for each group
# regression function: ffreg(target,features,datay,dataX)
y = 'mret'
tag = mret['group_tag'].unique().tolist()
tag.append('H-L')

# Panel A: CAPM MKT
id=0
for i in datay:
  print(f'for CAPM Model for target {tag[id]}: \n')
  id+=1
  ffreg(y,['MKT'],i,ff3)

# Panel B: FF3 MKT/SMB/HML
id=0
for i in datay:
  print(f'for FF3 Model for target {tag[id]}: \n')
  id+=1
  ffreg(y,['MKT','SMB','HML'],i,ff3)

# Panel C: FF4 MKT/SMB/HML/MOM
id=0
for i in datay:
  print(f'for FF4 Model for target {tag[id]}: \n')
  id+=1
  ffreg(y,['MKT','SMB','HML','MOM'],i,ffmom_merge)

# Panel D: FF5 MKT/SMB/HML/RMW/CMA
id=0
for i in datay:
  print(f'for FF5 Model for target {tag[id]}: \n')
  id+=1
  ffreg(y,['MKT','SMB','HML','RMW','CMA'],i,ff5)
# Out:
# for CAPM Model for target H:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     115.4
# Date:                Sat, 18 May 2024   Prob (F-statistic):           1.84e-26
# Time:                        18:20:55   Log-Likelihood:                -15299.
# No. Observations:                3190   AIC:                         3.060e+04
# Df Residuals:                    3188   BIC:                         3.061e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3328      0.522      2.555      0.011       0.310       2.356
# MKT            1.2197      0.114     10.741      0.000       0.997       1.442
# ==============================================================================
# Omnibus:                     8101.552   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        175748106.415
# Skew:                          27.587   Prob(JB):                         0.00
# Kurtosis:                    1151.564   Cond. No.                         4.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for CAPM Model for target L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     4.182
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0409
# Time:                        18:20:55   Log-Likelihood:                -22069.
# No. Observations:                3075   AIC:                         4.414e+04
# Df Residuals:                    3073   BIC:                         4.415e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.6816      5.759      1.160      0.246      -4.610      17.974
# MKT            2.4845      1.215      2.045      0.041       0.102       4.867
# ==============================================================================
# Omnibus:                     9957.516   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1051835636.701
# Skew:                          52.852   Prob(JB):                         0.00
# Kurtosis:                    2866.263   Cond. No.                         4.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for CAPM Model for target 2:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.255
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0713
# Time:                        18:20:55   Log-Likelihood:                -22717.
# No. Observations:                3270   AIC:                         4.544e+04
# Df Residuals:                    3268   BIC:                         4.545e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.7458      4.449      1.292      0.197      -2.976      14.468
# MKT            1.7573      0.974      1.804      0.071      -0.153       3.667
# ==============================================================================
# Omnibus:                    10740.762   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1312585751.901
# Skew:                          55.135   Prob(JB):                         0.00
# Kurtosis:                    3104.854   Cond. No.                         4.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for CAPM Model for target 3:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     7.968
# Date:                Sat, 18 May 2024   Prob (F-statistic):            0.00479
# Time:                        18:20:55   Log-Likelihood:                -23855.
# No. Observations:                3333   AIC:                         4.771e+04
# Df Residuals:                    3331   BIC:                         4.773e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.5422      5.437      1.203      0.229      -4.119      17.203
# MKT            3.4477      1.221      2.823      0.005       1.053       5.842
# ==============================================================================
# Omnibus:                    10894.963   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1298089240.724
# Skew:                          54.410   Prob(JB):                         0.00
# Kurtosis:                    3058.378   Cond. No.                         4.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for CAPM Model for target 4:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     25.83
# Date:                Sat, 18 May 2024   Prob (F-statistic):           3.91e-07
# Time:                        18:20:55   Log-Likelihood:                -20516.
# No. Observations:                3664   AIC:                         4.104e+04
# Df Residuals:                    3662   BIC:                         4.105e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3101      1.093      2.113      0.035       0.166       4.454
# MKT            1.1970      0.236      5.083      0.000       0.735       1.659
# ==============================================================================
# Omnibus:                    11349.835   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        977611953.773
# Skew:                          46.864   Prob(JB):                         0.00
# Kurtosis:                    2531.792   Cond. No.                         4.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for CAPM Model for target H-L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                 0.0009138
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.976
# Time:                        18:20:55   Log-Likelihood:                -1442.3
# No. Observations:                 297   AIC:                             2889.
# Df Residuals:                     295   BIC:                             2896.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2855      1.823     -0.157      0.876      -3.874       3.303
# MKT            0.0116      0.385      0.030      0.976      -0.747       0.770
# ==============================================================================
# Omnibus:                      252.117   Durbin-Watson:                   2.069
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            68751.102
# Skew:                          -2.392   Prob(JB):                         0.00
# Kurtosis:                      77.383   Cond. No.                         4.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF3 Model for target H:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     41.96
# Date:                Sat, 18 May 2024   Prob (F-statistic):           1.39e-26
# Time:                        18:20:55   Log-Likelihood:                -15294.
# No. Observations:                3190   AIC:                         3.060e+04
# Df Residuals:                    3186   BIC:                         3.062e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2684      0.521      2.433      0.015       0.246       2.291
# MKT            1.1744      0.119      9.876      0.000       0.941       1.408
# SMB            0.1978      0.183      1.082      0.279      -0.161       0.556
# HML            0.5088      0.162      3.136      0.002       0.191       0.827
# ==============================================================================
# Omnibus:                     8098.612   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        175199485.246
# Skew:                          27.563   Prob(JB):                         0.00
# Kurtosis:                    1149.768   Cond. No.                         4.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF3 Model for target L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.497
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0580
# Time:                        18:20:55   Log-Likelihood:                -22068.
# No. Observations:                3075   AIC:                         4.414e+04
# Df Residuals:                    3071   BIC:                         4.417e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.4685      5.759      1.123      0.261      -4.824      17.761
# MKT            1.8922      1.287      1.470      0.142      -0.632       4.416
# SMB            3.6193      2.230      1.623      0.105      -0.754       7.992
# HML           -1.1864      1.778     -0.667      0.505      -4.672       2.300
# ==============================================================================
# Omnibus:                     9955.475   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1050468411.627
# Skew:                          52.821   Prob(JB):                         0.00
# Kurtosis:                    2864.401   Cond. No.                         4.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF3 Model for target 2:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.212
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.304
# Time:                        18:20:55   Log-Likelihood:                -22717.
# No. Observations:                3270   AIC:                         4.544e+04
# Df Residuals:                    3266   BIC:                         4.547e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.7044      4.452      1.281      0.200      -3.025      14.434
# MKT            1.5714      1.021      1.539      0.124      -0.430       3.573
# SMB            0.9837      1.606      0.613      0.540      -2.165       4.132
# HML            0.2151      1.322      0.163      0.871      -2.378       2.808
# ==============================================================================
# Omnibus:                    10741.149   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1312939316.534
# Skew:                          55.141   Prob(JB):                         0.00
# Kurtosis:                    3105.272   Cond. No.                         4.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF3 Model for target 3:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.174
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0232
# Time:                        18:20:55   Log-Likelihood:                -23855.
# No. Observations:                3333   AIC:                         4.772e+04
# Df Residuals:                    3329   BIC:                         4.774e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.1596      5.446      1.131      0.258      -4.519      16.838
# MKT            3.2471      1.271      2.554      0.011       0.755       5.740
# SMB            0.7966      2.035      0.392      0.695      -3.193       4.786
# HML            2.0490      1.683      1.217      0.224      -1.251       5.349
# ==============================================================================
# Omnibus:                    10893.549   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1296736452.837
# Skew:                          54.390   Prob(JB):                         0.00
# Kurtosis:                    3056.785   Cond. No.                         4.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF3 Model for target 4:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     9.839
# Date:                Sat, 18 May 2024   Prob (F-statistic):           1.84e-06
# Time:                        18:20:55   Log-Likelihood:                -20515.
# No. Observations:                3664   AIC:                         4.104e+04
# Df Residuals:                    3660   BIC:                         4.106e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3184      1.093      2.121      0.034       0.175       4.462
# MKT            1.0590      0.249      4.256      0.000       0.571       1.547
# SMB            0.6332      0.420      1.507      0.132      -0.190       1.457
# HML            0.4168      0.333      1.251      0.211      -0.236       1.070
# ==============================================================================
# Omnibus:                    11351.673   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        978555656.410
# Skew:                          46.886   Prob(JB):                         0.00
# Kurtosis:                    2533.012   Cond. No.                         4.82
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF3 Model for target H-L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8700
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.457
# Time:                        18:20:55   Log-Likelihood:                -1441.0
# No. Observations:                 297   AIC:                             2890.
# Df Residuals:                     293   BIC:                             2905.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2414      1.824     -0.132      0.895      -3.831       3.348
# MKT           -0.1300      0.400     -0.325      0.745      -0.916       0.656
# SMB            0.6043      0.585      1.032      0.303      -0.548       1.756
# HML           -0.5406      0.531     -1.018      0.309      -1.586       0.504
# ==============================================================================
# Omnibus:                      240.733   Durbin-Watson:                   2.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63614.417
# Skew:                          -2.199   Prob(JB):                         0.00
# Kurtosis:                      74.563   Cond. No.                         4.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF4 Model for target H:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     34.65
# Date:                Sat, 18 May 2024   Prob (F-statistic):           2.33e-28
# Time:                        18:20:55   Log-Likelihood:                -15288.
# No. Observations:                3190   AIC:                         3.059e+04
# Df Residuals:                    3185   BIC:                         3.062e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4959      0.524      2.852      0.004       0.468       2.524
# MKT            1.0092      0.128      7.901      0.000       0.759       1.260
# SMB            0.2779      0.184      1.511      0.131      -0.083       0.639
# HML            0.3460      0.168      2.054      0.040       0.016       0.676
# MOM           -0.4263      0.122     -3.506      0.000      -0.665      -0.188
# ==============================================================================
# Omnibus:                     8095.008   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        174507184.261
# Skew:                          27.532   Prob(JB):                         0.00
# Kurtosis:                    1147.498   Cond. No.                         5.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF4 Model for target L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.063
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0831
# Time:                        18:20:55   Log-Likelihood:                -22067.
# No. Observations:                3075   AIC:                         4.414e+04
# Df Residuals:                    3070   BIC:                         4.417e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.9636      5.788      1.030      0.303      -5.386      17.313
# MKT            2.2996      1.370      1.679      0.093      -0.386       4.985
# SMB            3.6007      2.230      1.614      0.107      -0.772       7.974
# HML           -0.7585      1.845     -0.411      0.681      -4.375       2.858
# MOM            1.1285      1.295      0.871      0.384      -1.411       3.668
# ==============================================================================
# Omnibus:                     9953.335   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1048722963.501
# Skew:                          52.789   Prob(JB):                         0.00
# Kurtosis:                    2862.022   Cond. No.                         5.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF4 Model for target 2:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9277
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.447
# Time:                        18:20:55   Log-Likelihood:                -22717.
# No. Observations:                3270   AIC:                         4.544e+04
# Df Residuals:                    3265   BIC:                         4.547e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.8555      4.487      1.305      0.192      -2.942      14.653
# MKT            1.4652      1.092      1.342      0.180      -0.676       3.606
# SMB            1.0139      1.610      0.630      0.529      -2.143       4.170
# HML            0.1020      1.386      0.074      0.941      -2.615       2.819
# MOM           -0.2814      1.028     -0.274      0.784      -2.296       1.734
# ==============================================================================
# Omnibus:                    10741.066   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1312863515.727
# Skew:                          55.140   Prob(JB):                         0.00
# Kurtosis:                    3105.182   Cond. No.                         5.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF4 Model for target 3:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.381
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0495
# Time:                        18:20:55   Log-Likelihood:                -23855.
# No. Observations:                3333   AIC:                         4.772e+04
# Df Residuals:                    3328   BIC:                         4.775e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.1934      5.476      1.131      0.258      -4.544      16.930
# MKT            3.2147      1.381      2.327      0.020       0.506       5.923
# SMB            0.7976      2.035      0.392      0.695      -3.192       4.788
# HML            2.0275      1.721      1.178      0.239      -1.347       5.402
# MOM           -0.0711      1.183     -0.060      0.952      -2.390       2.248
# ==============================================================================
# Omnibus:                    10893.591   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1296772700.278
# Skew:                          54.390   Prob(JB):                         0.00
# Kurtosis:                    3056.828   Cond. No.                         5.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF4 Model for target 4:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     7.430
# Date:                Sat, 18 May 2024   Prob (F-statistic):           5.88e-06
# Time:                        18:20:55   Log-Likelihood:                -20515.
# No. Observations:                3664   AIC:                         4.104e+04
# Df Residuals:                    3659   BIC:                         4.107e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3754      1.100      2.159      0.031       0.218       4.533
# MKT            1.0132      0.268      3.776      0.000       0.487       1.539
# SMB            0.6331      0.420      1.507      0.132      -0.191       1.457
# HML            0.3772      0.344      1.095      0.273      -0.298       1.052
# MOM           -0.1159      0.254     -0.456      0.648      -0.614       0.382
# ==============================================================================
# Omnibus:                    11351.784   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        978602225.567
# Skew:                          46.887   Prob(JB):                         0.00
# Kurtosis:                    2533.072   Cond. No.                         5.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF4 Model for target H-L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.410
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.231
# Time:                        18:20:55   Log-Likelihood:                -1439.4
# No. Observations:                 297   AIC:                             2889.
# Df Residuals:                     292   BIC:                             2907.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6518      1.833     -0.356      0.722      -4.259       2.955
# MKT            0.1458      0.429      0.340      0.734      -0.698       0.989
# SMB            0.5045      0.586      0.861      0.390      -0.649       1.658
# HML           -0.2927      0.548     -0.534      0.594      -1.371       0.786
# MOM            0.6698      0.386      1.735      0.084      -0.090       1.429
# ==============================================================================
# Omnibus:                      235.000   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            60056.037
# Skew:                          -2.109   Prob(JB):                         0.00
# Kurtosis:                      72.536   Cond. No.                         5.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF5 Model for target H:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     25.37
# Date:                Sat, 18 May 2024   Prob (F-statistic):           3.60e-25
# Time:                        18:20:55   Log-Likelihood:                -15294.
# No. Observations:                3190   AIC:                         3.060e+04
# Df Residuals:                    3184   BIC:                         3.064e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2260      0.545      2.248      0.025       0.157       2.295
# MKT            1.1966      0.129      9.305      0.000       0.944       1.449
# SMB            0.1445      0.208      0.696      0.486      -0.262       0.551
# HML            0.3740      0.215      1.737      0.082      -0.048       0.796
# RMW           -0.0940      0.244     -0.385      0.700      -0.573       0.385
# CMA            0.3227      0.331      0.976      0.329      -0.326       0.971
# ==============================================================================
# Omnibus:                     8095.437   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        174800944.006
# Skew:                          27.535   Prob(JB):                         0.00
# Kurtosis:                    1148.462   Cond. No.                         5.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF5 Model for target L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.281
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0442
# Time:                        18:20:55   Log-Likelihood:                -22066.
# No. Observations:                3075   AIC:                         4.414e+04
# Df Residuals:                    3069   BIC:                         4.418e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5072      6.020      0.915      0.360      -6.297      17.311
# MKT            1.9144      1.388      1.379      0.168      -0.808       4.637
# SMB            4.9040      2.413      2.033      0.042       0.174       9.634
# HML           -0.8998      2.381     -0.378      0.706      -5.568       3.769
# RMW            4.5716      2.890      1.582      0.114      -1.094      10.238
# CMA           -4.7098      3.771     -1.249      0.212     -12.103       2.684
# ==============================================================================
# Omnibus:                     9950.527   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1046739471.012
# Skew:                          52.746   Prob(JB):                         0.00
# Kurtosis:                    2859.317   Cond. No.                         5.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF5 Model for target 2:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8600
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.507
# Time:                        18:20:55   Log-Likelihood:                -22717.
# No. Observations:                3270   AIC:                         4.545e+04
# Df Residuals:                    3264   BIC:                         4.548e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.3032      4.646      1.357      0.175      -2.807      15.413
# MKT            1.3163      1.100      1.196      0.232      -0.841       3.474
# SMB            1.0602      1.808      0.586      0.558      -2.484       4.605
# HML            0.9005      1.819      0.495      0.621      -2.666       4.467
# RMW            0.0846      2.104      0.040      0.968      -4.040       4.209
# CMA           -2.3283      2.842     -0.819      0.413      -7.901       3.245
# ==============================================================================
# Omnibus:                    10740.492   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1312374492.422
# Skew:                          55.131   Prob(JB):                         0.00
# Kurtosis:                    3104.604   Cond. No.                         5.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF5 Model for target 3:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.790
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0161
# Time:                        18:20:55   Log-Likelihood:                -23852.
# No. Observations:                3333   AIC:                         4.772e+04
# Df Residuals:                    3327   BIC:                         4.775e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.2710      5.667      1.283      0.200      -3.840      18.382
# MKT            3.2005      1.379      2.320      0.020       0.496       5.905
# SMB           -0.9884      2.239     -0.441      0.659      -5.378       3.401
# HML            1.0601      2.253      0.471      0.638      -3.357       5.478
# RMW           -4.3759      2.630     -1.664      0.096      -9.533       0.781
# CMA            4.6551      3.492      1.333      0.183      -2.191      11.501
# ==============================================================================
# Omnibus:                    10884.999   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1288726853.514
# Skew:                          54.268   Prob(JB):                         0.00
# Kurtosis:                    3047.336   Cond. No.                         5.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF5 Model for target 4:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     6.135
# Date:                Sat, 18 May 2024   Prob (F-statistic):           1.14e-05
# Time:                        18:20:55   Log-Likelihood:                -20514.
# No. Observations:                3664   AIC:                         4.104e+04
# Df Residuals:                    3658   BIC:                         4.108e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2554      1.134      1.989      0.047       0.033       4.478
# MKT            1.0352      0.265      3.907      0.000       0.516       1.555
# SMB            0.7997      0.451      1.771      0.077      -0.085       1.685
# HML            0.3532      0.444      0.796      0.426      -0.517       1.224
# RMW            0.2932      0.528      0.555      0.579      -0.743       1.329
# CMA           -0.3448      0.689     -0.500      0.617      -1.696       1.006
# ==============================================================================
# Omnibus:                    11349.301   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        976922623.736
# Skew:                          46.858   Prob(JB):                         0.00
# Kurtosis:                    2530.899   Cond. No.                         5.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for FF5 Model for target H-L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mret   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.7268
# Date:                Sat, 18 May 2024   Prob (F-statistic):              0.604
# Time:                        18:20:55   Log-Likelihood:                -1440.4
# No. Observations:                 297   AIC:                             2893.
# Df Residuals:                     291   BIC:                             2915.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6328      1.903     -0.333      0.740      -4.377       3.112
# MKT            0.0046      0.442      0.010      0.992      -0.866       0.875
# SMB            0.6917      0.675      1.025      0.306      -0.637       2.020
# HML           -1.1084      0.741     -1.495      0.136      -2.567       0.351
# RMW            0.1514      0.811      0.187      0.852      -1.445       1.748
# CMA            0.9719      1.090      0.891      0.374      -1.174       3.118
# ==============================================================================
# Omnibus:                      245.000   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64760.062
# Skew:                          -2.274   Prob(JB):                         0.00
# Kurtosis:                      75.197   Cond. No.                         5.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Panel E: HXZ MKT/SMB/IA/ROE -> annual data(the other models use monthly data)
hxz = pd.read_csv('HXZ.csv').dropna()
hxz.drop_duplicates(inplace=True)
hxz['roe'] = hxz['roe']*100

# %%
# merge market cap data to weight I/A
hxz_ia = pd.DataFrame(columns=['gvkey', 'roe', 'year', 'at', 'del_at', 'IA'])
for gvkey in hxz['gvkey'].unique().tolist():
  key_data = hxz[hxz['gvkey'] == gvkey].copy()
  key_data = key_data.sort_values(by='year')
  key_data['del_at'] = key_data['at'].diff() # at_t - at_t-1
  key_data['IA'] = key_data['del_at']/key_data['at'].shift(1)*100
  hxz_ia = pd.concat([hxz_ia, key_data], ignore_index=True)
hxz_ia
# Out:
#         gvkey        roe  year          at    del_at        IA
# 0        4819   6.700000  1991      89.423       NaN       NaN
# 1        4819 -22.325000  1992      89.871     0.448  0.500990
# 2        4819   8.150000  1993      97.837     7.966  8.863816
# 3        4819  10.550000  1994     101.685     3.848  3.933072
# 4        4819  12.425000  1995     102.053     0.368  0.361902
# ...       ...        ...   ...         ...       ...       ...
# 13782    4839  -3.800000  2019  114047.000  -602.000 -0.525081
# 13783    4839   6.925000  2020  116744.000  2697.000  2.364815
# 13784    4839  31.181818  2021  108996.000 -7748.000 -6.636744
# 13785  179597   3.200000  2019     152.757       NaN       NaN
# 13786  179597   9.125000  2020     151.483    -1.274 -0.834004
#
# [13787 rows x 6 columns]

# %%
# merge market cap data to weight I/A
hxz_merge = pd.merge(market_cap[['gvkey','year','MthCap']], hxz_ia, on=['year','gvkey'], how='inner')
IA={}
ROE={}
for year in hxz_merge['year'].unique():
  year_data = hxz_merge[hxz_merge['year'] == year].copy()
  sum = year_data['MthCap'].sum()
  year_data['weights'] = year_data['MthCap']/sum
  IA[year] = (year_data['weights']*year_data['IA']).sum()
  ROE[year] = (year_data['weights']*year_data['roe']).sum()

IA = pd.DataFrame(list(IA.items()), columns=['year', 'IA'])
ROE = pd.DataFrame(list(ROE.items()), columns=['year', 'ROE'])

# %%
# dataX preparation: merge I/A, ROE, MKT, SMB
at_df_yret = pd.read_csv('at_df_yret.csv')
H_L = pd.read_csv('at_HML.csv')
H_L.rename(columns={'H-L': 'yret','year':'fyear'}, inplace=True) # for regression convenience
ff3y = pd.read_csv('FF3Y.csv')
HXZ = IA.merge(ROE,on='year',how='inner')
HXZ = HXZ.merge(ff3y[['year','MKT','SMB']], on='year', how='inner')
# datay preparation: split by groups
tagl = at_df_yret[at_df_yret['group_tag']== 'L']
tag2 = at_df_yret[at_df_yret['group_tag']== '2']
tag3 = at_df_yret[at_df_yret['group_tag']== '3']
tag4 = at_df_yret[at_df_yret['group_tag']== '4']
tagh = at_df_yret[at_df_yret['group_tag']== 'H']
taghl = H_L
datayy =[tagl,tag2,tag3,tag4,tagh,taghl]
tagh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 323 entries, 0 to 1433
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fyear        323 non-null    int64
#  1   gvkey        323 non-null    int64
#  2   at           323 non-null    float64
#  3   p_at         323 non-null    float64
#  4   group_tag    323 non-null    object
#  5   trade        323 non-null    int64
#  6   weight_l     323 non-null    float64
#  7   weight_s     323 non-null    float64
#  8   weight       323 non-null    float64
#  9   yret         323 non-null    float64
#  10  cap          323 non-null    float64
#  11  rf           323 non-null    float64
#  12  Implied ERP  323 non-null    float64
#  13  ret_prem     323 non-null    float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 37.9+ KB

# %%
# Panle E Regression
tag = at_df_yret['group_tag'].unique().tolist()
tag.append('H-L')

id=0
for i in datayy:
  print(f'for HXZ Model for target {tag[id]}: \n')
  id+=1
  data = HXZ.merge(i,left_on=['year'],right_on=['fyear'],how='inner')
  X = sm.add_constant(data[['MKT','SMB','IA','ROE']]) # add constant term for alpha estimation
  y = data['yret']
  model = sm.OLS(y, X).fit()
  print(model.summary())
# Out:
# for HXZ Model for target H:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yret   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     5.075
# Date:                Sat, 18 May 2024   Prob (F-statistic):           0.000587
# Time:                        18:24:16   Log-Likelihood:                -1535.7
# No. Observations:                 276   AIC:                             3081.
# Df Residuals:                     271   BIC:                             3099.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.3973      7.395      2.217      0.027       1.838      30.957
# MKT            0.6831      0.228      2.997      0.003       0.234       1.132
# SMB            1.0149      0.549      1.848      0.066      -0.066       2.096
# IA             0.0411      0.051      0.800      0.424      -0.060       0.142
# ROE            0.4931      0.465      1.060      0.290      -0.423       1.409
# ==============================================================================
# Omnibus:                      134.400   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2145.755
# Skew:                           1.530   Prob(JB):                         0.00
# Kurtosis:                      16.313   Cond. No.                         172.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for HXZ Model for target L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yret   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     4.285
# Date:                Sat, 18 May 2024   Prob (F-statistic):            0.00224
# Time:                        18:24:16   Log-Likelihood:                -1606.1
# No. Observations:                 268   AIC:                             3222.
# Df Residuals:                     263   BIC:                             3240.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.6618     12.412      0.940      0.348     -12.778      36.102
# MKT            0.8342      0.330      2.528      0.012       0.184       1.484
# SMB            1.5183      0.832      1.826      0.069      -0.119       3.156
# IA             0.1533      0.079      1.945      0.053      -0.002       0.308
# ROE            0.4570      0.734      0.622      0.534      -0.989       1.903
# ==============================================================================
# Omnibus:                      350.614   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37099.865
# Skew:                           5.788   Prob(JB):                         0.00
# Kurtosis:                      59.466   Cond. No.                         188.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for HXZ Model for target 2:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yret   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     2.796
# Date:                Sat, 18 May 2024   Prob (F-statistic):             0.0265
# Time:                        18:24:16   Log-Likelihood:                -1777.5
# No. Observations:                 285   AIC:                             3565.
# Df Residuals:                     280   BIC:                             3583.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         42.4415     14.774      2.873      0.004      13.359      71.524
# MKT            0.5205      0.422      1.234      0.218      -0.310       1.351
# SMB            2.1555      1.015      2.123      0.035       0.157       4.154
# IA             0.0597      0.155      0.386      0.700      -0.245       0.364
# ROE           -0.5844      0.916     -0.638      0.524      -2.388       1.219
# ==============================================================================
# Omnibus:                      416.169   Durbin-Watson:                   2.248
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63109.714
# Skew:                           7.077   Prob(JB):                         0.00
# Kurtosis:                      74.513   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for HXZ Model for target 3:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yret   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     3.550
# Date:                Sat, 18 May 2024   Prob (F-statistic):            0.00763
# Time:                        18:24:16   Log-Likelihood:                -1622.7
# No. Observations:                 282   AIC:                             3255.
# Df Residuals:                     277   BIC:                             3274.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.7787     10.075      1.864      0.063      -1.056      38.613
# MKT            0.7082      0.281      2.520      0.012       0.155       1.262
# SMB            1.1237      0.687      1.635      0.103      -0.229       2.476
# IA             0.2638      0.525      0.502      0.616      -0.770       1.298
# ROE            0.1538      0.552      0.279      0.781      -0.933       1.240
# ==============================================================================
# Omnibus:                      294.507   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14777.326
# Skew:                           4.200   Prob(JB):                         0.00
# Kurtosis:                      37.454   Cond. No.                         52.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for HXZ Model for target 4:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yret   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     8.468
# Date:                Sat, 18 May 2024   Prob (F-statistic):           1.67e-06
# Time:                        18:24:16   Log-Likelihood:                -1964.0
# No. Observations:                 323   AIC:                             3938.
# Df Residuals:                     318   BIC:                             3957.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.8471     11.657      2.217      0.027       2.912      48.782
# MKT            0.9379      0.379      2.478      0.014       0.193       1.683
# SMB            1.7638      0.866      2.038      0.042       0.061       3.467
# IA             0.2667      0.071      3.751      0.000       0.127       0.407
# ROE           -0.3314      0.739     -0.448      0.654      -1.786       1.123
# ==============================================================================
# Omnibus:                      406.391   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41305.589
# Skew:                           5.659   Prob(JB):                         0.00
# Kurtosis:                      57.231   Cond. No.                         208.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# for HXZ Model for target H-L:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   yret   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     18.35
# Date:                Sat, 18 May 2024   Prob (F-statistic):           1.80e-06
# Time:                        18:24:16   Log-Likelihood:                -119.90
# No. Observations:                  25   AIC:                             249.8
# Df Residuals:                      20   BIC:                             255.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.0490     12.019      0.503      0.620     -19.022      31.120
# MKT            0.8542      0.401      2.128      0.046       0.017       1.691
# SMB           -0.7342      0.945     -0.777      0.446      -2.706       1.237
# IA             0.2637      0.061      4.308      0.000       0.136       0.391
# ROE           -1.4615      0.763     -1.915      0.070      -3.054       0.131
# ==============================================================================
# Omnibus:                        3.120   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.210   Jarque-Bera (JB):                1.559
# Skew:                          -0.480   Prob(JB):                        0.459
# Kurtosis:                       3.759   Cond. No.                         311.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
